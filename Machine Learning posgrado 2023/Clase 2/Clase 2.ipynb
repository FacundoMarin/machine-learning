# %% [markdown]
# Ejercicio 1
#
# Hay variables que puedan ser razonablemente consideradas normales? Hay variables
# que tienen un comportamiento sospechoso?
#
# Primero, observemos el gráfico para cada una de las variables:

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_cases = "casos_covid_bahia.csv"
file_beds = "camas_covid_bahia.csv"

# Reading the file
df = pd.read_csv(file_cases, header = 0)

#Plotting the data using pyplot

plt.scatter(df['fecha'], df['aislamiento_por_contacto_estrecho'])
plt.xlabel('fecha')
plt.ylabel('aislamiento_por_contacto_estrecho')
plt.title('Scatter Plot')
plt.show()
